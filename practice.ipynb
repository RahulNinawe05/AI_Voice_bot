# %%
import os
import base64
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
with open('image_1.jpg','rb') as f:
    ima_b64 = base64.b64encode(f.read()).decode('utf-8')

# %%
from groq import Groq
client = Groq()
model = "meta-llama/llama-4-scout-17b-16e-instruct"

# %%
query = "can You give me name of the diseases"

# %%
# merge the query and image
message = [
    {
        "role":'user',
        "content":[
            {
                'type':'text',
                'text': query
            },
            {
                'type':'image_url',
                'image_url': {
                    "url":f"data:image/jpeg;base64,{ima_b64}"
                }
            }
        ]
    }
]

# %%
chat= client.chat.completions.create(
    messages=message,
    model=model
)

# %%
print(chat.choices[0].message.content)
# Out:
# Based on the image, it appears to show a finger with symptoms that could be indicative of a skin condition. The visible symptoms include:
#
# * Redness and inflammation around the nail
# * Yellowish or orange spots or patches on the skin
#
# These symptoms could be related to several conditions, but one common condition that comes to mind is **Paronychia**, which is an inflammation of the skin around a nail. It can be caused by bacterial or fungal infections, and sometimes it can be associated with conditions like **Psoriasis** or **Eczema**.
#
# However, without more information or a proper medical evaluation, it's difficult to provide a definitive diagnosis. Other possible conditions could include:
#
# * **Dyshidrotic eczema** (also known as pompholyx)
# * **Contact dermatitis**
# * **Fungal infections** (like tinea)
#
# If you're concerned about the condition, I would recommend consulting a healthcare professional for a thorough evaluation and diagnosis. They can provide a more accurate assessment and recommend appropriate treatment.
